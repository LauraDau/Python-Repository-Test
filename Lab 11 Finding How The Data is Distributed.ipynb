# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install SciPy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 131.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 155.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 104.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 132.1 MB/s eta 0:00:0000:01
# ...

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch              object
# Age                     object
# Employment              object
# RemoteWork              object
#                         ...
# JobSatPoints_11        float64
# SurveyLength            object
# SurveyEase              object
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 114, dtype: object

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %%
df.dropna
print ("NaN's have been dropped")
# Out:
# NaN's have been dropped

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
print(df['Employment'].value_counts())
print(df['JobSat'].value_counts())
print(df['YearsCodePro'].value_counts())
# Out:
# Employment
# Employed, full-time                                                                                                                                   39041
# Independent contractor, freelancer, or self-employed                                                                                                   4846
# Student, full-time                                                                                                                                     4709
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                               3557
# Not employed, but looking for work                                                                                                                     2341
#                                                                                                                                                       ...
# ...

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
# piechart ofJobSat

# step1 Groupby

df_JobSat = df.groupby('JobSat', axis=0).sum()
print (type(df_JobSat.groupby('JobSat',axis=0)))
df_JobSat.head(2)
# Out:
# /tmp/ipykernel_299/2785939022.py:5: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   df_JobSat = df.groupby('JobSat', axis=0).sum()
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# /tmp/ipykernel_299/2785939022.py:6: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   print (type(df_JobSat.groupby('JobSat',axis=0)))
#         ResponseId                                         MainBranch  \
# JobSat
# 0.0        8623276  I am a developer by professionI am a developer...
# 1.0        7326638  I am a developer by professionI am a developer...
#
#                                                       Age  \
# JobSat
# 0.0     55-64 years old25-34 years old35-44 years old2...
# 1.0     25-34 years old25-34 years old45-54 years old4...
#
#                                                Employment  \
# JobSat
# ...

# %%
#Plot the data
df.JobSat['Total'].plot(kind='pie',
                        figsize = (5,6),
                        autopct ='%1.1f%%',
                        shortangle = 90,
                        shadow = True)
plt.title('Job Satisfaction Distribution')
plt.axis=('equal')
plt.legend (lables = df_JobSat.index,loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 #Plot the data
# ----> 2 df.JobSat['Total'].plot(kind='pie',
#       3                         figsize = (5,6),
#       4                         autopct ='%1.1f%%',
#       5                         shortangle = 90,
#       6                         shadow = True)
#       7 plt.title('Job Satisfaction Distribution')
#       8 plt.axis=('equal')
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# ...

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
# Cross-tabulate RemoteWork by Employment type
Language_ct = pd.crosstab(df['LanguageHaveWorkedWith'], df['LanguageWantToWorkWith'])
print("Cross-tabulation of Lanaguge Have Worked With vs Language Want To Work With:")
print(Language-ct)

import pylab as plt


#Create a grouped bar chart

x=df[


x=np.arrange(5)
y1=

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
# Group Remote Work by Region

df_Remotebyregion = df.groupby('RemoteWork','Region', axis=0).sum()
print (type(df_Remotebyregion.groupby('RemoteWork','Region',axis=0)))
df_Remotebyregion.head(2)


# Plot the heatmap with only these columns
plt.figure(figsize=(15, 10))
sns.heatmap(df_Remotebyregion, cbar=False, cmap='Blues', yticklabels=False)
plt.title('Heatmap of Remote Work Distribution by Region', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Group Remote Work by Region
# ----> 3 df_Remotebyregion = df.groupby('RemoteWork','Region', axis=0).sum()
#       4 print (type(df_Remotebyregion.groupby('RemoteWork','Region',axis=0)))
#       5 df_Remotebyregion.head(2)
#
# TypeError: DataFrame.groupby() got multiple values for argument 'axis'

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
 #Step 8: Correlation Between Experience and Job Satisfaction ---

# Convert to numeric in case of string values
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['JobSatPoints_1'] = pd.to_numeric(df['JobSatPoints_1'], errors='coerce')

pearson_coef, p_value = stats.pearsonr(
    df['YearsCodePro'].dropna(),
    df['JobSatPoints_1'].dropna()
)
print(f"Pearson Correlation Coefficient: {pearson_coef}")
print(f"P-value: {p_value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       4 df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
#       5 df['JobSatPoints_1'] = pd.to_numeric(df['JobSatPoints_1'], errors='coerce')
# ----> 7 pearson_coef, p_value = stats.pearsonr(
#       8    df['YearsCodePro'].dropna(),
#       9    df['JobSatPoints_1'].dropna()
#      10 )
#      11 print(f"Pearson Correlation Coefficient: {pearson_coef}")
#      12 print(f"P-value: {p_value}")
#
# NameError: name 'stats' is not defined

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
# Cross-tabulate Employment by EdLevel
ed_employment_ct = pd.crosstab(df['Employment'], df['EdLevel'])
print("Cross-tabulation of Employment Type vs EducationLevel")
print(ed_employment_ct)




# Visualize Remote Work distribution by Employment Type with a stacked bar plot

# create the data

x=['Associate degree (A.A., A.S., etc.)', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)','Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
'Primary/elementary school', 'Professional degree (JD, MD, Ph.D, Ed.D, etc.)','Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 
'Some college/university study without earning a degree','Something else' ]

y1=np.array([Employment,Employed, full-time,Employed, full-time;Employed, part-time,Employed, full-time;Independent contractor, fre... ,Employed, full-time;
Independent contractor, fre.,Student, full-time;Student, part-time;Employed,...,Student, full-time;Student, part-time;Retired,Student, part-time,Student, part-time;Employed, 
part-time,Student, part-time;Employed, part-time,Student, part-time;Retired])

plt.bar(x,y1,color='r')
plt.bar(x,y2
plt.xlabel("EdLevel")
plt.ylabel("Employment")
plt.legend()
plt.title('Remote Work Preferences by Employment Type')
plt.show()
# Out:
# Cross-tabulation of Employment Type vs EducationLevel
# EdLevel                                             Associate degree (A.A., A.S., etc.)  \
# Employment
# Employed, full-time                                                                1059
# Employed, full-time;Employed, part-time                                               9
# Employed, full-time;Independent contractor, fre...                                  104
# Employed, full-time;Independent contractor, fre...                                   11
# Employed, full-time;Independent contractor, fre...                                    0
# ...                                                                                 ...
# Student, full-time;Student, part-time;Employed,...                                    0
# Student, full-time;Student, part-time;Retired                                         0
# Student, part-time                                                                   12
# ...

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
